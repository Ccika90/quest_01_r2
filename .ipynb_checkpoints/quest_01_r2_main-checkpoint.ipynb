# %%
# define rooms and items

# this is game_room, its objects and door

couch = {
    "name": "couch",
    "type": "furniture",
}

creature_1 = {
    "name": "an imminent threat",
    "type": "furniture",
}

door_a = {
    "name": "door a",
    "type": "door",
}

key_a = {
    "name": "key for door a",
    "type": "key",
    "target": door_a,
}

piano = {
    "name": "piano",
    "type": "furniture",
}

game_room = {
    "name": "game room",
    "type": "room",
}

# this is bedroom_1, its objects and doors

queen_bed = {
    "name": "queen bed",
    "type": "furniture",
}

creature_2 = {
    "name": "a sense of terror getting closer",
    "type": "furniture",
}

door_b = {
    "name": "door b",
    "type": "door",
}

key_b = {
    "name": "key for door b",
    "type": "key",
    "target": door_b,
}

door_c = {
    "name": "door c",
    "type": "door",
}

bedroom_1 = {
    "name": "bedroom 1",
    "type": "room",
}

# this is living_room, its object and door

dining_table = {
    "name": "dining table",
    "type": "furniture",

}

creature_3 = {
    "name": "a scratching sound",
    "type": "furniture",
}

door_d = {
    "name": "door d",
    "type": "door",
}

living_room = {
    "name": "living room",
    "type": "room",
}

# bedroom_2

double_bed = {
    "name": "double bed",
    "type": "furniture",
}

creature_4 = {
    "name": "some nearby steps dragging faster",
    "type": "furniture",
}

dresser = {
    "name": "dresser",
    "type": "furniture",
}

door_b = {
    "name": "door b",
    "type": "door",
}

key_c = {
    "name": "key for door c",
    "type": "key",
    "target": door_c,

}

key_d = {
    "name": "key for door d",
    "type": "key",
    "target": door_d,

}

bedroom_2 = {
    "name": "bedroom 2",
    "type": "room",
}

# outside

outside = {
  "name": "outside"

}

door_d = {
    "name": "door d",
    "type": "door",
}

all_rooms = [game_room, bedroom_1, bedroom_2, living_room, outside]

all_doors = [door_a, door_b, door_c, door_d]

# define which items/rooms are related

object_relations = {
    "game room": [couch, piano, door_a, creature_1],
    "piano": [key_a],
    "door a": [game_room, bedroom_1],
    "bedroom 1": [queen_bed, door_b, door_c, creature_2],
    "queen bed": [key_b],
    "bedroom 2": [double_bed, dresser, door_b, creature_3],
    "double bed": [key_c],
    "dresser": [key_d],
    "living room": [dining_table, door_c, door_d, creature_4],
    "door b": [bedroom_1, bedroom_2],
    "door c": [bedroom_1, living_room],
    "door d": [living_room, outside],
    "outside": [door_d]
}

INIT_GAME_STATE = {
    "current_room": game_room,
    "keys_collected": [],
    "target_room": outside
}

# %%
import quest_01_r2_functions
game_state = INIT_GAME_STATE.copy()

quest_01_r2_functions.start_game(game_state, object_relations)
# Out:
# Suddenly, you find yourself waking up on an unfamiliar couch, in an eerie house devoid of windows. Your memory fails to provide any explanation about how you ended up here, or what transpired previously. You can sense an imminent threat lurking somewhere - your gut tells you to escape the house immediately!
# You are now in game room.
# What would you like to do? Type 'explore' or 'examine'? explore
# You decide to explore the room,. This is game room. You find couch, piano, door a, an imminent threat
# You are now in game room.
# What would you like to do? Type 'explore' or 'examine'? examine
# What would you like to examine? couch
# You examine couch. There isn't anything interesting about it.
# You are now in game room.
